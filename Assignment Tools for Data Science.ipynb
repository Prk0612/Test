# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Pratik Patel**
#
# Current role: Financial Analyst
#
# Desired occupation: Data Scientist

# %% [markdown]
# _I am interested in Data science because I wanted to help companies grow and solve their process problems to meet their goals._

# %% [markdown]
# ### Welcome to Annual Meet

# %%
Year = "2022"


print ("Hello world, Welcome to Data science Meet",Year)
# Out:
# Hello world, Welcome to Data science Meet 2022

# %% [markdown]
# ##### Table
#
# |Sr no | Year |
# |----- | ---- |
# |  1       |2020   |
# |  2       |2021   |
# |  3       |2022   |
#
# ##### Bulleted list
#
# * 2020
# * 2021
# * 2022
#
# ##### Hyperlink
#
# [IBM Cloud Login page](https://cloud.ibm.com/login)
#
# ##### Numbered list
#
# 1. 2020
# 2. 2021
# 3. 2022
